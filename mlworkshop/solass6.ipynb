# %% [markdown]
# ## installing the fast ai and nlpaug for the assignment
# ```
# `# This is formatted as code`
# ```

# %%
# !pip install fastai
# !pip install nlpaug
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from fastai.vision.all import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
# !pip install nltk

# %%
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-5b3af5cb-1fff-4600-bb2a-63c59682abd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b3af5cb-1fff-4600-bb2a-63c59682abd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
f=next(iter(up))
path = Path(f)
img =PILImage.create(path)

# %%
plt.imshow( img)

# %%
deg=np.linspace(-30,60,10)
fig,ax=plt.subplots(10)
c=0
for i in deg:
  ax[c].imshow(img.rotate(i))
  c+=1

# %%
plt.imshow(img.transpose(Image.FLIP_LEFT_RIGHT))

# %%
plt.imshow(img.transpose( Image.FLIP_TOP_BOTTOM))

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
text= "The  quick brown fox jump over the lazy dog  "
aug = naw.SynonymAug( )
print( aug.augment(text))
# Out:
# ['The flying brown fox jumping over the slothful dog']
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mcpenguin/rollercoasters")

print("Path to dataset files:", path)
df= pd.read_csv('/content/data.csv')
print(df.head(501))
print(df.tail(501))
df.info()
numeric=[]
nonnumeric=[]
for i in df.columns:
  if (df[i].dtype == "float64"):
    numeric.append(i)
  else:
    nonnumeric.append(i)

print( numeric , nonnumeric)
subdf=pd.DataFrame(numeric)
print(subdf)
# Out:
# ...
# 100%|██████████| 523k/523k [00:00<00:00, 67.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mcpenguin/rollercoasters/versions/13
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-945208bc3490> in <cell line: 7>()
#       5
#       6 print("Path to dataset files:", path)
# ----> 7 df= pd.read_csv('/content/data.csv')
#       8 print(df.head(501))
#       9 print(df.tail(501))
#
# ...

# %% [markdown]
# ##Q8

# %%
Dataset=[2, 19, 22, 27, 29, 30, 32, 35, 52, 59]
mean = np.mean(Dataset)
print(mean)
sd=np.std(Dataset)
print(sd)
out=[]
for i in (Dataset):
  z=(i-mean)/sd
  print(z)
  if z>3 or z<-3:
    out.append(i)
print(out)
plt.boxplot(Dataset)
# Out:
# 30.7
# 15.258112596255147
# -1.8809665886882982
# -0.7668051946917452
# -0.5701884781041183
# -0.24249395045807326
# -0.11141613939965526
# -0.04587723387044625
# 0.08520057718797175
# 0.2818172937755988
# 1.3959786877721518
# 1.854751026476615
# []
# {'whiskers': [<matplotlib.lines.Line2D at 0x79eec0df0070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79eec0df3f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79eec0df0490>],
#  'medians': [<matplotlib.lines.Line2D at 0x79eec3122110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79eec31216f0>],
#  'means': []}

# %% [markdown]
# #q9 and q10

# %%
import random
mean = 6
std =12
sno=200
z=[]
x=[random.randint(1,1000) for i in range(200) ]
print(x)
for i in x:
  z.append((i-mean)/std)
print(z)
q1=np.quantile(z,0.25)
q3=np.quantile(z,0.75)
print(q1,q3)
iqr=q3-q1
print(iqr)
llim=q1-1.5*iqr
ulim=q3+1.5*iqr
print(llim,ulim)
out=[]
for i in z:
  if i<llim or i>ulim:
    out.append(i)
print(out)
# Out:
# [572, 273, 451, 641, 927, 40, 176, 670, 445, 34, 947, 317, 728, 342, 626, 833, 110, 661, 276, 190, 148, 730, 510, 222, 205, 701, 523, 426, 742, 989, 419, 420, 503, 780, 440, 539, 959, 755, 631, 627, 300, 147, 562, 277, 459, 56, 852, 840, 29, 956, 348, 355, 248, 556, 596, 374, 837, 179, 441, 353, 615, 841, 929, 703, 97, 559, 307, 368, 298, 858, 904, 212, 530, 408, 117, 295, 191, 43, 331, 335, 620, 735, 978, 664, 843, 933, 688, 870, 530, 321, 744, 582, 609, 929, 22, 740, 330, 606, 820, 158, 942, 674, 303, 35, 183, 3, 413, 733, 798, 688, 389, 839, 288, 748, 970, 98, 547, 986, 849, 55, 396, 539, 692, 293, 877, 332, 414, 707, 218, 582, 849, 356, 960, 258, 20, 26, 502, 37, 490, 179, 943, 191, 661, 483, 512, 13, 819, 315, 283, 231, 700, 619, 24, 520, 706, 641, 80, 284, 384, 521, 309, 906, 586, 486, 52, 794, 594, 516, 549, 217, 458, 22, 894, 204, 370, 804, 698, 411, 397, 457, 281, 56, 3, 468, 506, 4, 219, 343, 369, 999, 272, 831, 526, 242, 613, 975, 914, 8, 445, 544]
# ...

# %% [markdown]
# ## Q11

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
data = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
data['target'] = diabetes.target
print(data.describe())
Q1 = data['bmi'].quantile(0.25)
Q3 = data['bmi'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = data[(data['bmi'] < lower_bound) | (data['bmi'] > upper_bound)]
data_no_outliers = data[(data['bmi'] >= lower_bound) & (data['bmi'] <= upper_bound)]
print("Original dataset shape:", data.shape)
print("Dataset shape after removing outliers:", data_no_outliers.shape)
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...
